# %% [markdown]
# <a href="https://colab.research.google.com/github/Jake0925/Function/blob/main/Kaggle%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%85%8BColab%EC%97%90_%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C%EB%B0%9B%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://itmaster98.tistory.com/111
#
# https://velog.io/@bbirong/colab%EC%97%90%EC%84%9C-Kaggle-Dataset-%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C-%EB%B0%9B%EA%B8%B0

# %%
# !pip install kaggle

#kaggle.json 파일 불러오기
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c0714b39-0458-4874-a4bd-0b730a3277f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c0714b39-0458-4874-a4bd-0b730a3277f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
for fn in uploaded.keys():
    print('user uploaded file"{name}"with length {length} bytes'.format(name=fn, length=len(uploaded[fn])))
# Out:
# user uploaded file"kaggle (1).json"with length 70 bytes

# %%
# kaggle 폴더 생성
# !mkdir -p !/.kaggle/
# kaggle.json 파일 복사
# !cp kaggle.json ~/.kaggle/kaggle.json
#파일 권한 부여
# !chmod 600 /root/.kaggle/kaggle.json

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 데이터셋 다운로드
# Copy API command하여 복사된주소에 !를 붙이면 다운로드가 된다
# !kaggle datasets download -d nexuswho/aitex-fabric-image-database
# Out:
# Dataset URL: https://www.kaggle.com/datasets/nexuswho/aitex-fabric-image-database
# License(s): Attribution-NonCommercial-NoDerivatives 4.0 International (CC BY-NC-ND 4.0)
# ...
#  98% 164M/168M [00:01<00:00, 143MB/s]
# 100% 168M/168M [00:01<00:00, 149MB/s]

# %%
#압축풀기
! unzip aitex-fabric-image-database.zip
# Out:
# Archive:  aitex-fabric-image-database.zip
#   inflating: Defect_images/0001_002_00.png
#   inflating: Defect_images/0002_002_00.png
#   inflating: Defect_images/0003_002_00.png
#   inflating: Defect_images/0004_002_01.png
#   inflating: Defect_images/0005_002_01.png
#   inflating: Defect_images/0006_002_01.png
#   inflating: Defect_images/0010_006_02.png
#   inflating: Defect_images/0011_006_02.png
#   inflating: Defect_images/0012_006_02.png
#   inflating: Defect_images/0013_006_02.png
#   inflating: Defect_images/0014_006_02.png
#   inflating: Defect_images/0015_006_02.png
#   inflating: Defect_images/0016_006_02.png
#   inflating: Defect_images/0017_002_02.png
#   inflating: Defect_images/0018_010_03.png
#   inflating: Defect_images/0019_016_03.png
#   inflating: Defect_images/0020_016_03.png
#   inflating: Defect_images/0021_016_03.png
#   inflating: Defect_images/0022_019_02.png
#   inflating: Defect_images/0023_019_02.png
#   inflating: Defect_images/0024_019_02.png
# ...
